# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../Graphics/Chapter01/Figure1.03.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
img.shape
# Out:
# (407, 640, 3)

# %%
canvas = np.zeros((img.shape[0] * 2, img.shape[1], 3), dtype = np.uint8)
canvas.shape
# Out:
# (814, 640, 3)

# %%
plt.imshow(canvas)

# %%
canvas[:img.shape[0], :, :] = img
plt.imshow(canvas)

# %%
# Vertical flip

flipped_img = img[::-1, :, :]
plt.imshow(flipped_img)

# %%
canvas[img.shape[0]:, :, :] = flipped_img

# %%
plt.imshow(canvas)
